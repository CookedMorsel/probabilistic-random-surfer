# %%
import logging
from prob_surfer.parsing.html import get_url_data_as_html

logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    handlers=[
        # logging.FileHandler("app.log"),  # Log messages to a file
        logging.StreamHandler(),  # Log messages to the console
    ],
)
logger = logging.getLogger(__name__)

url = "https://en.wikipedia.org/wiki/Random_surfing_model"


html_data = get_url_data_as_html(url)
# with open("out.html", "w", encoding="utf-8") as f:
#     f.write(html_data)
# Out:
# 2024-09-04 18:43:41,015 - prob_surfer.parsing.html - DEBUG - retrieving https://en.wikipedia.org/wiki/Random_surfing_model
# 2024-09-04 18:43:41,025 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): en.wikipedia.org:443
# 2024-09-04 18:43:41,298 - urllib3.connectionpool - DEBUG - https://en.wikipedia.org:443 "GET /wiki/Random_surfing_model HTTP/11" 200 17229

# %%
from lxml import html, etree



data_tree = html.fromstring(html_data)

# Convert to a pretty-printed XML string
xml_content = etree.tostring(data_tree, pretty_print=True, encoding='unicode')

# print(xml_content)

# %%
root = html.fromstring(html_data)

# %%
def print_node(node, curr_depth: int):
    num_children = len(node)
    text = node.text or ""
    prefix = "  " * curr_depth

    if  not isinstance(node.tag, str):
        logger.debug(f"found invalid node with type {type(node.tag)}, skipping")
        assert num_children == 0, f"cant skip, node has {num_children} children"
        return

    print(f"{prefix}{node.tag: >10} | {num_children:>4} children | "
          f"{len(text):>6} len text | {len(node.attrib):>2} attributes")

def print_tree(root, curr_depth: int = 0):
    print_node(root, curr_depth)
    for node in root:
        print_tree(node, curr_depth+1)

# %%
print_tree(root)
# Out:
# 2024-09-04 18:52:00,022 - __main__ - DEBUG - found invalid node with type <class '_cython_3_0_11.cython_function_or_method'>
# 2024-09-04 18:52:00,024 - __main__ - DEBUG - found invalid node with type <class '_cython_3_0_11.cython_function_or_method'>
# 2024-09-04 18:52:00,025 - __main__ - DEBUG - found invalid node with type <class '_cython_3_0_11.cython_function_or_method'>
# 2024-09-04 18:52:00,026 - __main__ - DEBUG - found invalid node with type <class '_cython_3_0_11.cython_function_or_method'>
# 2024-09-04 18:52:00,027 - __main__ - DEBUG - found invalid node with type <class '_cython_3_0_11.cython_function_or_method'>
# 2024-09-04 18:52:00,027 - __main__ - DEBUG - found invalid node with type <class '_cython_3_0_11.cython_function_or_method'>
# 2024-09-04 18:52:00,028 - __main__ - DEBUG - found invalid node with type <class '_cython_3_0_11.cython_function_or_method'>
# ...

# %%
for element in root:
    num_children = len(element)
    text = element.text or ""
    print(f"{element.tag: >10} | {num_children:>4} children | {len(text):>6} len text | {len(element.attrib):>2} attributes")
    print("------")
    # break
# Out:
#       head |   28 children |      1 len text |  0 attributes
# ------
#       body |    6 children |      0 len text |  1 attributes
# ------

# %%
element
# Out:
# <!-- CentralNotice -->

# %%
type(element.tag)
# Out:
# _cython_3_0_11.cython_function_or_method

# %%
element.tag()
# Out:
# <!---->

# %%
for attrib_name, attrib_val in element.attrib.items():
    print(f"{attrib_name}: {attrib_val }")
# Out:
# class: client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available
# lang: en
# dir: ltr

# %%
element
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 element.index()
#
# File src\\lxml\\etree.pyx:1242, in lxml.etree._Element.index()
#
# TypeError: index() takes at least 1 positional argument (0 given)

# %%
dir(element)
# Out:
# ['__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_init',
#  'addnext',
#  'addprevious',
#  'append',
#  'attrib',
#  'base',
#  'base_url',
#  'body',
#  'classes',
#  'clear',
#  'cssselect',
#  'drop_tag',
#  'drop_tree',
#  'extend',
#  'find',
#  'find_class',
#  'find_rel_links',
#  'findall',
#  'findtext',
#  'forms',
#  'get',
#  'get_element_by_id',
#  'getchildren',
#  'getiterator',
#  'getnext',
#  'getparent',
# ...
